# %%
#Read data csv from:
#https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#reading data from file
df = pd.read_csv('covid.csv')

#Screening columns, data head and certain data location
#print(df.columns)
#print(df.head())
#print(df.loc[30000,:])

#Selecting certain country in data columns
df1 = df.loc[df['location'] == 'Indonesia']
df1=df1[['location','date','new_cases']]
print(df1.tail())
df2 = df.loc[df['location'] == 'United Kingdom']
df2=df2[['location','date','new_cases']]
#print(df2.loc[df2['date'] == '2021-03-15'])
#print(df2.tail())

#Reseting data index
df1.reset_index(drop=True, inplace=True)
df2.reset_index(drop=True, inplace=True)
#print(df1.tail())

#Trimming data to the same length
#print(df2)
#print(len(df2) - len(df1))
df2=df2.iloc[len(df2) - len(df1):]
df2.reset_index(drop=True, inplace=True)
#print(df2.tail())

#Setting the last XX days data, 720 = 24 months
df1=df1.iloc[len(df1)-720:]
df2=df2.iloc[len(df2)-720:]
#print(df1)
#print(df2)

plt.plot(df1['new_cases'])
plt.plot(df2['new_cases'],'r')
plt.grid()
# Out:
#         location        date  new_cases
# 98323  Indonesia  2022-11-16     8486.0
# 98324  Indonesia  2022-11-17     7822.0
# 98325  Indonesia  2022-11-18     6699.0
# 98326  Indonesia  2022-11-19     6383.0
# 98327  Indonesia  2022-11-20     5172.0

# %%
#Selecting certain country in data columns
df1 = df.loc[df['location'] == 'Indonesia']
df1=df1[['location','date','new_deaths', 'new_cases','positive_rate', 'new_cases_smoothed','new_deaths_smoothed']]
#print(df1.tail())
df2 = df.loc[df['location'] == 'United Kingdom']
df2=df2[['location','date','new_deaths', 'new_cases','positive_rate', 'new_cases_smoothed','new_deaths_smoothed']]
#print(df2.tail())

#Reseting data index
df1.reset_index(drop=True, inplace=True)
df2.reset_index(drop=True, inplace=True)
#print(df1.tail())

#Trimming data to the same length
#print(df2)
#print(len(df2) - len(df1))
df2=df2.iloc[len(df2) - len(df1):]
df2.reset_index(drop=True, inplace=True)
#print(df2.tail())

#Setting the last XX days data, 720 = 24 months; 300 = 10 months
xdays=720
df1=df1.iloc[len(df1)-xdays:]
df2=df2.iloc[len(df2)-xdays:]
#print(df1)
#print(df2)

#For colormap to show time elapsing
numbers=range(len(df1))
print(numbers)

df1.plot.scatter(x='new_cases_smoothed',y='new_deaths_smoothed',s=50, c=numbers, colormap='plasma')
plt.grid()
df2.plot.scatter(x='new_cases_smoothed',y='new_deaths_smoothed',s=50, c=numbers, colormap='plasma')
plt.grid()
# Out:
# range(0, 720)

# %%
#Selecting certain country in data columns
df1 = df.loc[df['location'] == 'Indonesia']
df1=df1[['location','date','new_deaths', 'stringency_index']]
#print(df1.tail())
df2 = df.loc[df['location'] == 'United Kingdom']
df2=df2[['location','date','new_deaths', 'stringency_index']]
#print(df2.tail())

#Reseting data index
df1.reset_index(drop=True, inplace=True)
df2.reset_index(drop=True, inplace=True)
#print(df1.tail())

#Trimming data to the same length
#print(df2)
#print(len(df2) - len(df1))
df2=df2.iloc[len(df2) - len(df1):]
df2.reset_index(drop=True, inplace=True)
#print(df2.tail())

#Setting the last XX days data, 720 = 24 months
xdays=720
df1=df1.iloc[len(df1)-xdays:]
df2=df2.iloc[len(df2)-xdays:]
#print(df1)
#print(df2)

#For colormap to show time elapsing
numbers=range(len(df1))
print(numbers)

df1.plot.scatter(x='stringency_index',y='new_deaths',s=50, c=numbers, colormap='plasma')
plt.grid()
df2.plot.scatter(x='stringency_index',y='new_deaths',s=50, c=numbers, colormap='plasma')
plt.grid()
# Out:
# range(0, 720)

# %%
#Selecting certain country in data columns
df1 = df.loc[df['location'] == 'Indonesia']
df1=df1[['location','date','new_cases', 'stringency_index']]
#print(df1.tail())
df2 = df.loc[df['location'] == 'United Kingdom']
df2=df2[['location','date','new_cases', 'stringency_index']]
#print(df2.tail())

#Reseting data index
df1.reset_index(drop=True, inplace=True)
df2.reset_index(drop=True, inplace=True)
#print(df1.tail())

#Trimming data to the same length
#print(df2)
#print(len(df2) - len(df1))
df2=df2.iloc[len(df2) - len(df1):]
df2.reset_index(drop=True, inplace=True)
#print(df2.tail())

#Setting the last XX days data, 720 = 24 months
xdays=720
df1=df1.iloc[len(df1)-xdays:]
df2=df2.iloc[len(df2)-xdays:]
#print(df1)
#print(df2)

#For colormap to show time elapsing
numbers=range(len(df1))
print(numbers)

df1.plot.scatter(x='stringency_index',y='new_cases',s=50, c=numbers, colormap='plasma')
plt.grid()
df2.plot.scatter(x='stringency_index',y='new_cases',s=50, c=numbers, colormap='plasma')
plt.grid()
# Out:
# range(0, 720)

# %%
#Selecting certain country in data columns
df1 = df.loc[df['location'] == 'Indonesia']
df1=df1[['location','date','stringency_index','reproduction_rate']]
print(df1.tail())
df2 = df.loc[df['location'] == 'South Korea']
df2=df2[['location','date','stringency_index','reproduction_rate']]
print(df2.tail())

df1=df1.dropna()
df2=df2.dropna()

#Reseting data index
df1.reset_index(drop=True, inplace=True)
df2.reset_index(drop=True, inplace=True)
print(df1.tail())

#Trimming data to the same length
#print(df2)
#print(len(df2) - len(df1))
#df2=df2.iloc[len(df2) - len(df1):]
#df2.reset_index(drop=True, inplace=True)
print(df2.tail())

#Setting the last XX days data, 720 = 24 months
#xdays=720
#df1=df1.iloc[len(df1)-xdays:]
#df2=df2.iloc[len(df2)-xdays:]
#print(df1)
#print(df2)

#For colormap to show time elapsing
numbers1=range(len(df1))
print(numbers1)
numbers2=range(len(df2))
print(numbers2)

df1.plot.scatter(x='stringency_index',y='reproduction_rate',s=50, c=numbers1, colormap='plasma')
plt.grid()
df2.plot.scatter(x='stringency_index',y='reproduction_rate',s=50, c=numbers2, colormap='plasma')
plt.grid()
# Out:
#         location        date  stringency_index  reproduction_rate
# 98323  Indonesia  2022-11-16               NaN                NaN
# 98324  Indonesia  2022-11-17               NaN                NaN
# 98325  Indonesia  2022-11-18               NaN                NaN
# 98326  Indonesia  2022-11-19               NaN                NaN
# 98327  Indonesia  2022-11-20               NaN                NaN
#            location        date  stringency_index  reproduction_rate
# 198024  South Korea  2022-11-16               NaN                NaN
# 198025  South Korea  2022-11-17               NaN                NaN
# 198026  South Korea  2022-11-18               NaN                NaN
# 198027  South Korea  2022-11-19               NaN                NaN
# 198028  South Korea  2022-11-20               NaN                NaN
#       location        date  stringency_index  reproduction_rate
# 950  Indonesia  2022-10-22             29.90               1.17
# 951  Indonesia  2022-10-23             29.90               1.18
# 952  Indonesia  2022-10-24             29.89               1.20
# 953  Indonesia  2022-10-25             29.89               1.21
# 954  Indonesia  2022-10-26             29.89               1.21
#         location        date  stringency_index  reproduction_rate
# 974  South Korea  2022-10-22             11.11               1.17
# 975  South Korea  2022-10-23             11.11               1.22
# 976  South Korea  2022-10-24             11.11               1.29
# 977  South Korea  2022-10-25             11.11               1.26
# 978  South Korea  2022-10-26             11.11               1.23
# range(0, 955)
# range(0, 979)

# %%
#Selecting certain country in data columns
df1 = df.loc[df['location'] == 'Indonesia']
df1=df1[['location','date','new_vaccinations','reproduction_rate']]
print(df1.tail())
df2 = df.loc[df['location'] == 'South Korea']
df2=df2[['location','date','new_vaccinations','reproduction_rate']]
print(df2.tail())

df1=df1.dropna()
df2=df2.dropna()

#Reseting data index
df1.reset_index(drop=True, inplace=True)
df2.reset_index(drop=True, inplace=True)
print(df1.tail())

#Trimming data to the same length
#print(df2)
#print(len(df2) - len(df1))
#df2=df2.iloc[len(df2) - len(df1):]
#df2.reset_index(drop=True, inplace=True)
print(df2.tail())

#Setting the last XX days data, 720 = 24 months
#xdays=720
#df1=df1.iloc[len(df1)-xdays:]
#df2=df2.iloc[len(df2)-xdays:]
#print(df1)
#print(df2)

#For colormap to show time elapsing
numbers1=range(len(df1))
numbers2=range(len(df2))
print(numbers1)
print(numbers2)

df1.plot.scatter(x='new_vaccinations',y='reproduction_rate',s=50, c=numbers1, colormap='plasma')
plt.grid()
df2.plot.scatter(x='new_vaccinations',y='reproduction_rate',s=50, c=numbers2, colormap='plasma')
plt.grid()
# Out:
#         location        date  new_vaccinations  reproduction_rate
# 98323  Indonesia  2022-11-16               NaN                NaN
# 98324  Indonesia  2022-11-17               NaN                NaN
# 98325  Indonesia  2022-11-18               NaN                NaN
# 98326  Indonesia  2022-11-19               NaN                NaN
# 98327  Indonesia  2022-11-20               NaN                NaN
#            location        date  new_vaccinations  reproduction_rate
# 198024  South Korea  2022-11-16            4016.0                NaN
# 198025  South Korea  2022-11-17            4618.0                NaN
# 198026  South Korea  2022-11-18            6328.0                NaN
# 198027  South Korea  2022-11-19            2822.0                NaN
# 198028  South Korea  2022-11-20              94.0                NaN
#       location        date  new_vaccinations  reproduction_rate
# 404  Indonesia  2022-05-28               0.0               1.01
# 405  Indonesia  2022-05-29               0.0               1.05
# 406  Indonesia  2022-05-30               0.0               1.08
# 407  Indonesia  2022-05-31               0.0               1.11
# 408  Indonesia  2022-06-01               0.0               1.14
#         location        date  new_vaccinations  reproduction_rate
# 602  South Korea  2022-10-22            3892.0               1.17
# 603  South Korea  2022-10-23             104.0               1.22
# 604  South Korea  2022-10-24            6888.0               1.29
# 605  South Korea  2022-10-25            5959.0               1.26
# 606  South Korea  2022-10-26            6002.0               1.23
# range(0, 409)
# range(0, 607)

# %%
#Selecting certain country in data columns
df1 = df.loc[df['location'] == 'Indonesia']
df1=df1[['location','date','new_vaccinations','new_deaths']]
print(df1.tail())
df2 = df.loc[df['location'] == 'United Kingdom']
df2=df2[['location','date','new_vaccinations','new_deaths']]
print(df2.tail())

df1=df1.dropna()
df2=df2.dropna()

#Reseting data index
df1.reset_index(drop=True, inplace=True)
df2.reset_index(drop=True, inplace=True)
print(df1.tail())

#Trimming data to the same length
#print(df2)
#print(len(df2) - len(df1))
#df2=df2.iloc[len(df2) - len(df1):]
#df2.reset_index(drop=True, inplace=True)
print(df2.tail())

#Setting the last XX days data, 600 = 20 months
#xdays=720
#df1=df1.iloc[len(df1)-xdays:]
#df2=df2.iloc[len(df2)-xdays:]
#print(df1)
#print(df2)

#For colormap to show time elapsing
numbers1=range(len(df1))
numbers2=range(len(df2))
print(numbers1)
print(numbers2)

df1.plot.scatter(x='new_vaccinations',y='new_deaths',s=50, c=numbers1, colormap='plasma')
plt.grid()
df2.plot.scatter(x='new_vaccinations',y='new_deaths',s=50, c=numbers2, colormap='plasma')
plt.grid()
# Out:
#         location        date  new_vaccinations  new_deaths
# 98323  Indonesia  2022-11-16               NaN        54.0
# 98324  Indonesia  2022-11-17               NaN        38.0
# 98325  Indonesia  2022-11-18               NaN        32.0
# 98326  Indonesia  2022-11-19               NaN        25.0
# 98327  Indonesia  2022-11-20               NaN        31.0
#               location        date  new_vaccinations  new_deaths
# 222118  United Kingdom  2022-11-16               NaN         0.0
# 222119  United Kingdom  2022-11-17               NaN       666.0
# 222120  United Kingdom  2022-11-18               NaN         NaN
# 222121  United Kingdom  2022-11-19               NaN         NaN
# 222122  United Kingdom  2022-11-20               NaN         NaN
#       location        date  new_vaccinations  new_deaths
# 404  Indonesia  2022-05-28               0.0         8.0
# 405  Indonesia  2022-05-29               0.0         1.0
# 406  Indonesia  2022-05-30               0.0        12.0
# 407  Indonesia  2022-05-31               0.0         5.0
# 408  Indonesia  2022-06-01               0.0         3.0
#            location        date  new_vaccinations  new_deaths
# 594  United Kingdom  2022-08-31           15755.0        71.0
# 595  United Kingdom  2022-09-01           11010.0        42.0
# 596  United Kingdom  2022-09-02            9783.0        46.0
# 597  United Kingdom  2022-09-03           15677.0        53.0
# 598  United Kingdom  2022-09-04            5992.0        43.0
# range(0, 409)
# range(0, 599)
